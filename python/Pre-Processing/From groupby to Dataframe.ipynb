# %%
import pandas as pd
import numpy as np

# %%
graduated = pd.read_csv('data/dati/recent_grads.csv')

# %%
graduated.columns
# Out:
# Index([u'Rank', u'Major_code', u'Major', u'Major_category', u'Total',
#        u'Sample_size', u'Men', u'Women', u'ShareWomen', u'Employed',
#        u'Full_time', u'Part_time', u'Full_time_year_round', u'Unemployed',
#        u'Unemployment_rate', u'Median', u'P25th', u'P75th', u'College_jobs',
#        u'Non_college_jobs', u'Low_wage_jobs'],
#       dtype='object')

# %%
a = graduated.groupby(['Rank','Major_code'])
b = a['Total'].mean()

# %%
b.head()
# Out:
# Rank  Major_code
# 1     2419           2339
# 2     2416            756
# 3     2415            856
# 4     2417           1258
# 5     2405          32260
# Name: Total, dtype: int64

# %%
b.reset_index()
# Out:
#      Rank  Major_code   Total
# 0       1        2419    2339
# 1       2        2416     756
# 2       3        2415     856
# 3       4        2417    1258
# 4       5        2405   32260
# 5       6        2418    2573
# 6       7        6202    3777
# 7       8        5001    1792
# 8       9        2414   91227
# 9      10        2408   81527
# 10     11        2407   41542
# 11     12        2401   15058
# 12     13        2404   14955
# 13     14        5008    4279
# 14     15        2409    4321
# 15     16        2402    8925
# 16     17        2412   18968
# 17     18        2400   61152
# 18     19        2403    2825
# 19     20        3201    1148
# 20     21        2102  128319
# 21     22        1104    4361
# 22     23        2502   11565
# 23     24        2413    2993
# 24     25        6212   18713
# 25     26        2406   53153
# 26     27        5601   18498
# 27     28        6204   11732
# 28     29        2499    9133
# 29     30        5402    5978
# ...
