# %%
import pandas as pd
import numpy as np

# %%
all_age = pd.read_csv('data/dati/all_age.csv')

# %%
all_age.describe()
# Out:
#         Major_code         Total      Employed  Employed_full_time_year_round  \
# count   173.000000  1.730000e+02  1.730000e+02                   1.730000e+02
# mean   3879.815029  2.302566e+05  1.661620e+05                   1.263078e+05
# std    1687.753140  4.220685e+05  3.073244e+05                   2.424254e+05
# min    1100.000000  2.396000e+03  1.492000e+03                   1.093000e+03
# 25%    2403.000000  2.428000e+04  1.728100e+04                   1.272200e+04
# 50%    3608.000000  7.579100e+04  5.656400e+04                   3.961300e+04
# 75%    5503.000000  2.057630e+05  1.428790e+05                   1.110250e+05
# max    6403.000000  3.123510e+06  2.354398e+06                   1.939384e+06
#
#           Unemployed  Unemployment_rate         Median         P25th  \
# count     173.000000         173.000000     173.000000    173.000000
# mean     9725.034682           0.057355   56816.184971  38697.109827
# ...

# %%
all_age.head()
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %%
for i in all_age.Major.unique():
    if i == i:
        print(str(i) + str(" ") + str(np.sum(all_age.Major == i)))
    else:
        print("NaN: " + str(np.sum(all_age.Major.isnull())))
# Out:
# GENERAL AGRICULTURE 1
# AGRICULTURE PRODUCTION AND MANAGEMENT 1
# AGRICULTURAL ECONOMICS 1
# ANIMAL SCIENCES 1
# FOOD SCIENCE 1
# PLANT SCIENCE AND AGRONOMY 1
# SOIL SCIENCE 1
# MISCELLANEOUS AGRICULTURE 1
# ENVIRONMENTAL SCIENCE 1
# FORESTRY 1
# NATURAL RESOURCES MANAGEMENT 1
# ARCHITECTURE 1
# AREA ETHNIC AND CIVILIZATION STUDIES 1
# COMMUNICATIONS 1
# JOURNALISM 1
# MASS MEDIA 1
# ADVERTISING AND PUBLIC RELATIONS 1
# COMMUNICATION TECHNOLOGIES 1
# COMPUTER AND INFORMATION SYSTEMS 1
# COMPUTER PROGRAMMING AND DATA PROCESSING 1
# COMPUTER SCIENCE 1
# INFORMATION SCIENCES 1
# COMPUTER ADMINISTRATION MANAGEMENT AND SECURITY 1
# COMPUTER NETWORKING AND TELECOMMUNICATIONS 1
# COSMETOLOGY SERVICES AND CULINARY ARTS 1
# GENERAL EDUCATION 1
# EDUCATIONAL ADMINISTRATION AND SUPERVISION 1
# SCHOOL STUDENT COUNSELING 1
# ELEMENTARY EDUCATION 1
# MATHEMATICS TEACHER EDUCATION 1
# PHYSICAL AND HEALTH EDUCATION TEACHING 1
# EARLY CHILDHOOD EDUCATION 1
# SCIENCE AND COMPUTER TEACHER EDUCATION 1
# ...
