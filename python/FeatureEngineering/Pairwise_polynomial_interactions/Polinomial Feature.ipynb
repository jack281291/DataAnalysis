# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import PolynomialFeatures

# %%
from azureml import Workspace
ws = Workspace(
    workspace_id='556d475f8b30495db749adc7d9379947',
    authorization_token='5a9f262ff3ab4807801d0dcad7c68e4c',
    endpoint='https://studioapi.azureml.net'
)
ds = ws.datasets['hour.csv']
hour = ds.to_dataframe()

# %%
hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81          0       3          13   16
# 1           1  0.22  0.2727  0.80          0       8          32   40
# 2           1  0.22  0.2727  0.80          0       5          27   32
# 3           1  0.24  0.2879  0.75          0       3          10   13
# 4           1  0.24  0.2879  0.75          0       0           1    1

# %%
hour.drop(["instant","dteday"],axis=1,inplace=True)

# %%
pf = PolynomialFeatures(degree=2)

# %%
X_new = pf.fit_transform(X = hour[["hum","windspeed"]])

# %%
X_new
# Out:
# array([[ 1.        ,  0.81      ,  0.        ,  0.6561    ,  0.        ,
#          0.        ],
#        [ 1.        ,  0.8       ,  0.        ,  0.64      ,  0.        ,
#          0.        ],
#        [ 1.        ,  0.8       ,  0.        ,  0.64      ,  0.        ,
#          0.        ],
#        ...,
#        [ 1.        ,  0.6       ,  0.1642    ,  0.36      ,  0.09852   ,
#          0.02696164],
#        [ 1.        ,  0.56      ,  0.1343    ,  0.3136    ,  0.075208  ,
#          0.01803649],
#        [ 1.        ,  0.65      ,  0.1343    ,  0.4225    ,  0.087295  ,
#          0.01803649]])

# %%
X = pd.DataFrame({"hum_2": X_new[:,3], "hum_windspeed": X_new[:,4], \
                 "windspeed": X_new[:,5]})

# %%
X.head()
# Out:
#     hum_2  hum_windspeed  windspeed
# 0  0.6561              0          0
# 1  0.6400              0          0
# 2  0.6400              0          0
# 3  0.5625              0          0
# 4  0.5625              0          0
