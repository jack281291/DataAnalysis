# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import roc_auc_score
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /usr/local/lib/python3.4/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
glass = pd.read_csv('dati/glass.data.csv')

# %%
glass.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fade04cef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade05fad30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fade0380e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faddf44d128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faddf400358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faddf3af240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faddf3e1cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faddf38d4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faddf33f518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faddf347e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faddf31fdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faddf2d4c18>]], dtype=object)

# %%
glass.columns
# Out:
# Index(['Id number', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe',
#        'Type of glass'],
#       dtype='object')

# %%
glass.drop('Id number', axis = 1, inplace=True)

# %%
X_train = glass.drop('Type of glass', axis = 1)
y_train = glass['Type of glass']

# %%
from sklearn.tree import DecisionTreeClassifier
trees = DecisionTreeClassifier()

# %%
trees.fit(X_train, y_train)
yhat = trees.predict(X_train)
pd.crosstab(yhat, y_train)
# Out:
# Type of glass   1   2   3   5  6   7
# row_0
# 1              70   0   0   0  0   0
# 2               0  76   0   0  0   0
# 3               0   0  17   0  0   0
# 5               0   0   0  13  0   0
# 6               0   0   0   0  9   0
# 7               0   0   0   0  0  29

# %%
trees.score(X_train, y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train,yhat)
# Out:
# array([[70,  0,  0,  0,  0,  0],
#        [ 0, 76,  0,  0,  0,  0],
#        [ 0,  0, 17,  0,  0,  0],
#        [ 0,  0,  0, 13,  0,  0],
#        [ 0,  0,  0,  0,  9,  0],
#        [ 0,  0,  0,  0,  0, 29]])
